# %%
# %pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in ./env/lib/python3.11/site-packages (1.4.2)
# Requirement already satisfied: numpy>=1.19.5 in ./env/lib/python3.11/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in ./env/lib/python3.11/site-packages (from scikit-learn) (1.13.0)
# Requirement already satisfied: joblib>=1.2.0 in ./env/lib/python3.11/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./env/lib/python3.11/site-packages (from scikit-learn) (3.5.0)
#
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: pip3.11 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %%
columns = ['NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC', 'NU_NOTA_MT', 'NU_NOTA_REDACAO']
df = pd.read_csv("MICRODADOS_ENEM_2022.csv", sep=";", encoding="ISO-8859-1", usecols=columns)
print(df.shape)
print(df.head())
# Out:
# (3476105, 5)
#    NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO
# 0         NaN         NaN         NaN         NaN              NaN
# 1         NaN         NaN         NaN         NaN              NaN
# 2       421.1       546.0       498.8       565.3            760.0
# 3       490.7       388.6       357.8       416.0            320.0
# 4         NaN         NaN         NaN         NaN              NaN

# %%
df.dropna(inplace=True, subset=['NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC', 'NU_NOTA_MT','NU_NOTA_REDACAO'])
df = df.sample(n=100000)
y = df['NU_NOTA_REDACAO']
x = df.drop(axis=1, columns="NU_NOTA_REDACAO")

# %% [markdown]
# Dividindo os dados em treino e teste

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
print(len(y_train))
print(len(y_test))
print(len(X_test))
# Out:
# 80000
# 20000
# 20000

# %%
rf_regressor = RandomForestRegressor(n_estimators=100, random_state=42)
rf_regressor.fit(X_train, y_train)
y_pred = rf_regressor.predict(X_test)

# %%
rmse_best = np.sqrt(mean_squared_error(y_test, y_pred))
print(f'Best Root Mean Squared Error: {rmse_best}')
# Out:
# Best Root Mean Squared Error: 168.4606740874558

# %%
plt.figure(figsize=(10, 5))
plt.plot(y_test[:100], y_test[:100], label='Line Plot', color='blue', marker='o')
plt.scatter(y_test[:100], y_pred[:100], label='Scatter Plot', color='red')
plt.xlabel('valores reais')
plt.ylabel('valores preditos')
plt.title('valores reais x preditos')
# plt.grid(True)
# Out:
# Text(0.5, 1.0, 'valores reais x preditos')
